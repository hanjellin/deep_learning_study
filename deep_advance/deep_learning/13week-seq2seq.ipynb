# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence

# %%
from collections import Counter, OrderedDict
import spacy
import random
import numpy as np
import time
#from datasets import load_dataset

# %%
device = torch.device('mps')

# %%
raw_data = [
    ("ich bin gluckliich", "i am happy"),
    ("du bist trauring","you are sad"),
    ("er ist stark", "he is strong"),
    ("wir sind schnell", "we are fast"),
    ("sie sind langsam", "they are slow"),
    ("ich mag das buch", "i like the book"),
    ("sie liebt muslk", "she loves music"),
]

try:
    spacy_de = spacy.load("de_core_news_sm")
    spacy_en = spacy.load("en_core_web_sm")
except OSError:
    print("Spacy 모델이 없습니다. 다음을 실행하시어 python -m spacy download de_core_news_sm en_core_web_sm")
    exit()

def tokenize_de(text):
    return [tok.text.lower() for tok in spacy_de.tokenizer(text)]
def tokenize_en(text):
    return [tok.text.lower() for tok in spacy_en.tokenizer(text)]
